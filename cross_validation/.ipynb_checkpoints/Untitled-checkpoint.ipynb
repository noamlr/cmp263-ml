# %%
import pandas as pd
import numpy as np
import matplotlib as mp
import random

# %%
''' PARAMETERS '''
# INPUT_FILE = f'{var1}/{var2}'
INPUT_FILE = f'enunciado/diabetes.csv'

# %%
def normalize(df, cols):
    '''
    df: Input dataframe
    cols: Columns to normalize
    '''
    for col in cols:
        val_max = max(df[col])
        val_min = min(df[col])
        df[col] = (df[col] - val_min)/(val_max - val_min)
        # print(f'Column: {col}, min: {val_min}, max:{val_max}.')
    return df

# %%
def get_folds(k=5, df=None, col=''):
    
    df['fold'] = -1
    
    df_w_folds = pd.DataFrame(columns=df.columns)
    
    uniq_class_list = df[col].unique()
    
    for val in uniq_class_list:
        df_temp = df[df[col] == val]
        ar_fold = np.arange(len(df_temp))
        random.shuffle(ar_fold)
        
        # Split array in n folds 
        f = lambda x: x%k+1
        ar_fold = f(ar_fold)
        df_temp['fold'] = ar_fold
        df_w_folds = df_w_folds.append(df_temp)
    
    df_w_folds = df_w_folds.sort_values(by=['fold'])
    return df_w_folds

# %%
def cross_validation(k_fold, ar_k_knn, df, cols, col_real, beta):
    df = get_folds(k_fold, df, col_real)
        
    labels = df[col_real].unique()
    labels.sort()
    classes_size = len(labels)
    pos_lab_dict = dict(zip(labels, [i for i in range(classes_size)]))    
#     print(pos_lab_dict)
    for k_knn in ar_k_knn:
        print(f'K for k-NN: {k_knn}')
        df_out = pd.DataFrame(columns=['fold', 'accuracia', 'f-measure'])
        for fold in range(k_fold):
            df_train = df[df['fold'] != fold+1]
            df_test = df[df['fold'] == fold+1]
    #         print(f'df_train: {len(df_train)}, df_test: {len(df_test)}')
            ''' create the confusion matrix:
            Rows: Real Values
            Cols: Predicted Values
            '''
            confusion_matrix = np.zeros((classes_size, classes_size))

            for index, row in df_test.iterrows():
                pred = knn(k=k_knn, df_train=df_train, row_test=row, cols=cols, col_real=col_real)
                # Get position in the confusion matrix of prediction
                col_pred_pos = pos_lab_dict[pred]
                row_real_pos = pos_lab_dict[row[col_real]]
                confusion_matrix[row_real_pos][col_pred_pos] += 1

    #         print(confusion_matrix)

            # Diagonal contains the right classification    
            acc = np.trace(confusion_matrix)/np.sum(confusion_matrix) 
            prec_accum = 0
            rec_accum = 0
    #         for label in labels:
            for label in [1]:
                pos = pos_lab_dict[label]
                # VP/VP+FP
                prec_accum = confusion_matrix[pos][pos] / sum( confusion_matrix[i][pos] for i in range(classes_size)) 
                # VP/VP+FN
                rec_accum = confusion_matrix[pos][pos] / sum( confusion_matrix[pos][i] for i in range(classes_size)) 

            ''' f (macro): The average of all precision and recall: For multiclass '''
            prec = prec_accum #/ classes_size
            rec = rec_accum #/ classes_size
    #         print(f'prec: {prec}, rec: {rec}')
            f1 = (1+beta**2)*( (prec*rec) / ((beta**2)*prec + rec ) )
            df_out = df_out.append({'fold':(int)(fold+1), 'accuracia': acc, 'f-measure': f1}, ignore_index=True)

        print(df_out)
        avg_acc = np.average(df_out['accuracia'])
        avg_f1 = np.average(df_out['f-measure'])
        std_acc = np.std(df_out['accuracia'])
        std_f1 = np.std(df_out['f-measure'])

        print(f'Average Acc: {avg_acc}, Average f1-measure: {avg_f1}')
        print(f'Std Acc: {std_acc}, Std f1-measure: {std_f1}')

    #     return df_out

# %%
def knn(k=5, df_train=None, row_test=None, cols=[], col_real=''):
    df = df_train.copy()
    df['euc_dist'] = 0
    for col in cols:
        df['euc_dist'] += (df[col]-row_test[col])**2
    df['euc_dist'] = np.sqrt(df['euc_dist'])
    df = df.sort_values(by=['euc_dist'], ascending=True)
    
    # Get the k nearest possible values
    res_list = df.head(k)[col_real].to_list()
    # Return the most repeated element
    return max(set(res_list), key = res_list.count)

#     print(df.head(k).to_list)
#     print(row_test)
#     return df

# %% [markdown]
# ## INIT
# Call main

# %%
''' Read dataframe '''
df = pd.read_csv(INPUT_FILE)
# Columns to normalize 
ar_columns = ['Pregnancies', 'Glucose', 'BloodPressure', 'SkinThickness', 'Insulin', 'BMI', 
              'DiabetesPedigreeFunction', 'Age']
df_norm = normalize(df, ar_columns)
r = 10
ar_k_knn = [3, 5, 7]
for i in range(r):
    print(f'R: {i+1}')
    cross_validation(10, ar_k_knn, df_norm, ar_columns, 'Outcome', 1)
# Out:
# R: 1
# K for k-NN: 3
# /home/noa/Documents/UFRGS/CURSOS/Aprendizado de Máquina/TAREFAS/VALIDAÇÃO CRUZADA/env/lib/python3.6/site-packages/ipykernel_launcher.py:17: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
# /home/noa/Documents/UFRGS/CURSOS/Aprendizado de Máquina/TAREFAS/VALIDAÇÃO CRUZADA/env/lib/python3.6/site-packages/ipykernel_launcher.py:17: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#    fold  accuracia  f-measure
# 0   1.0   0.792208   0.692308
# Average Acc: 0.7922077922077922, Average f1-measure: 0.6923076923076923
# Std Acc: 0.0, Std f1-measure: 0.0
#    fold  accuracia  f-measure
# 0   1.0   0.792208   0.692308
# 1   2.0   0.792208   0.666667
# Average Acc: 0.7922077922077922, Average f1-measure: 0.6794871794871795
# Std Acc: 0.0, Std f1-measure: 0.012820512820512832
#    fold  accuracia  f-measure
# 0   1.0   0.792208   0.692308
# 1   2.0   0.792208   0.666667
# 2   3.0   0.649351   0.584615
# Average Acc: 0.7445887445887447, Average f1-measure: 0.6478632478632479
# Std Acc: 0.0673435029701474, Std f1-measure: 0.045931722538613315
#    fold  accuracia  f-measure
# 0   1.0   0.792208   0.692308
# 1   2.0   0.792208   0.666667
# 2   3.0   0.649351   0.584615
# 3   4.0   0.688312   0.500000
# Average Acc: 0.7305194805194806, Average f1-measure: 0.610897435897436
# Std Acc: 0.06320754004523309, Std f1-measure: 0.07537709276961019
#    fold  accuracia  f-measure
# 0   1.0   0.792208   0.692308
# 1   2.0   0.792208   0.666667
# 2   3.0   0.649351   0.584615
# 3   4.0   0.688312   0.500000
# 4   5.0   0.597403   0.392157
# Average Acc: 0.7038961038961039, Average f1-measure: 0.5671493212669684
# Std Acc: 0.07766190331286263, Std f1-measure: 0.11045793328865455
#    fold  accuracia  f-measure
# 0   1.0   0.792208   0.692308
# 1   2.0   0.792208   0.666667
# 2   3.0   0.649351   0.584615
# 3   4.0   0.688312   0.500000
# 4   5.0   0.597403   0.392157
# 5   6.0   0.714286   0.541667
# Average Acc: 0.7056277056277057, Average f1-measure: 0.562902212166918
# Std Acc: 0.07100095007297286, Std f1-measure: 0.10128006813060192
#    fold  accuracia  f-measure
# 0   1.0   0.792208   0.692308
# 1   2.0   0.792208   0.666667
# 2   3.0   0.649351   0.584615
# 3   4.0   0.688312   0.500000
# 4   5.0   0.597403   0.392157
# 5   6.0   0.714286   0.541667
# 6   7.0   0.766234   0.653846
# Average Acc: 0.7142857142857143, Average f1-measure: 0.5758942038353804
# Std Acc: 0.06907053977360404, Std f1-measure: 0.09902032316564305
#    fold  accuracia  f-measure
# 0   1.0   0.792208   0.692308
# 1   2.0   0.792208   0.666667
# 2   3.0   0.649351   0.584615
# 3   4.0   0.688312   0.500000
# 4   5.0   0.597403   0.392157
# 5   6.0   0.714286   0.541667
# 6   7.0   0.766234   0.653846
# 7   8.0   0.831169   0.745098
# Average Acc: 0.7288961038961039, Average f1-measure: 0.5970446832579186
# Std Acc: 0.07529038068380021, Std f1-measure: 0.10821643039978882
#    fold  accuracia  f-measure
# 0   1.0   0.792208   0
# 2   3.0   0.701299   0.581818
# Average Acc: 0.722943722943723, Average f1-measure: 0.5928715068303169
# Std Acc: 0.016197651024995423, Std f1-measure: 0.02819687956942756
#    fold  accuracia  f-measure
# 0   1.0   0.740260   0.565217
# 1   2.0   0.727273   0.631579
# 2   3.0   0.701299   0.581818
# 3   4.0   0.688312   0.500000
# Average Acc: 0.7142857142857143, Average f1-measure: 0.5696536301227377
# Std Acc: 0.020534270520573897, Std f1-measure: 0.04704792672918382
#    fold  accuracia  f-measure
# 0   1.0   0.740260   0.565217
# 1   2.0   0.727273   0.631579
# 2   3.0   0.701299   0.581818
# 3   4.0   0.688312   0.500000
# 4   5.0   0.688312   0.600000
# Average Acc: 0.7090909090909091, Average f1-measure: 0.5757229040981902
# Std Acc: 0.021101398453599905, Std f1-measure: 0.0437966925003263
#    fold  accuracia  f-measure
# 0   1.0   0.740260   0.565217
# 1   2.0   0.727273   0.631579
# 2   3.0   0.701299   0.581818
# 3   4.0   0.688312   0.500000
# 4   5.0   0.688312   0.600000
# 5   6.0   0.662338   0.380952
# Average Acc: 0.7012987012987013, Average f1-measure: 0.5432611502405553
# Std Acc: 0.025974025974025983, Std f1-measure: 0.08286908880401953
#    fold  accuracia  f-measure
# 0   1.0   0.740260   0.565217
# 1   2.0   0.727273   0.631579
# 2   3.0   0.701299   0.581818
# 3   4.0   0.688312   0.500000
# 4   5.0   0.688312   0.600000
# 5   6.0   0.662338   0.380952
# 6   7.0   0.753247   0.612245
# Average Acc: 0.7087198515769944, Average f1-measure: 0.5531159713432164
# Std Acc: 0.03014485493371415, Std f1-measure: 0.08042978324671954
#    fold  accuracia  f-measure
# 0   1.0   0.740260   0.565217
# 1   2.0   0.727273   0.631579
# 2   3.0   0.701299   0.581818
# 3   4.0   0.688312   0.500000
# 4   5.0   0.688312   0.600000
# 5   6.0   0.662338   0.380952
# 6   7.0   0.753247   0.612245
# 7   8.0   0.740260   0.583333
# Average Acc: 0.7126623376623377, Average f1-measure: 0.5568931415919811
# Std Acc: 0.030065355807552176, Std f1-measure: 0.0758959839819741
#    fold  accuracia  f-measure
# 0   1.0   0.740260   0.565217
# 1   2.0   0.727273   0.631579
# 2   3.0   0.701299   0.581818
# 3   4.0   0.688312   0.500000
# 4   5.0   0.688312   0.600000
# 5   6.0   0.662338   0.380952
# 6   7.0   0.753247   0.612245
# 7   8.0   0.740260   0.583333
# 8   9.0   0.842105   0.769231
# Average Acc: 0.7270448849396218, Average f1-measure: 0.5804862113296242
# Std Acc: 0.049581758433113056, Std f1-measure: 0.09784294372513398
#    fold  accuracia  f-measure
# 0   1.0   0.740260   0.565217
# 1   2.0   0.727273   0.631579
# 2   3.0   0.701299   0.581818
# 3   4.0   0.688312   0.500000
# 4   5.0   0.688312   0.600000
# 5   6.0   0.662338   0.380952
# 6   7.0   0.753247   0.612245
# 7   8.0   0.740260   0.583333
# 8   9.0   0.842105   0.769231
# 9  10.0   0.710526   0.541667
# Average Acc: 0.7253930280246069, Average f1-measure: 0.5766042568633285
# Std Acc: 0.04729771002698503, Std f1-measure: 0.09354968523423958
# K for k-NN: 5
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# ~/Documents/UFRGS/CURSOS/Aprendizado de Máquina/TAREFAS/VALIDAÇÃO CRUZADA/env/lib/python3.6/site-packages/numpy/core/numerictypes.py in issubclass_(arg1, arg2)
#     322     try:
# --> 323         return issubclass(arg1, arg2)
#     324     except TypeError:
#
# TypeError: issubclass() arg 1 must be a class
#
# During handling of the above exception, another exception occurred:
#
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-187-7100d5aedcc0> in <module>
#       9 for i in range(r):
#      10     print(f'R: {i+1}')
# ---> 11     cross_validation(10, ar_k_knn, df_norm, ar_columns, 'Outcome', 1)
#
# <ipython-input-185-c12d8f5d52dc> in cross_validation(k_fold, ar_k_knn, df, cols, col_real, beta)
#      21
#      22             for index, row in df_test.iterrows():
# ---> 23                 pred = knn(k=k_knn, df_train=df_train, row_test=row, cols=cols, col_real=col_real)
#      24                 # Get position in the confusion matrix of prediction
#      25                 col_pred_pos = pos_lab_dict[pred]
#
# <ipython-input-186-5e92b4398a77> in knn(k, df_train, row_test, cols, col_real)
#       5         df['euc_dist'] += (df[col]-row_test[col])**2
#       6     df['euc_dist'] = np.sqrt(df['euc_dist'])
# ----> 7     df = df.sort_values(by=['euc_dist'], ascending=True)
#       8
#       9     # Get the k nearest possible values
#
# ~/Documents/UFRGS/CURSOS/Aprendizado de Máquina/TAREFAS/VALIDAÇÃO CRUZADA/env/lib/python3.6/site-packages/pandas/core/frame.py in sort_values(self, by, axis, ascending, inplace, kind, na_position, ignore_index, key)
#    5305
#    5306         new_data = self._mgr.take(
# -> 5307             indexer, axis=self._get_block_manager_axis(axis), verify=False
#    5308         )
#    5309
#
# ~/Documents/UFRGS/CURSOS/Aprendizado de Máquina/TAREFAS/VALIDAÇÃO CRUZADA/env/lib/python3.6/site-packages/pandas/core/internals/managers.py in take(self, indexer, axis, verify, convert)
#    1429         Take items along any axis.
#    1430         """
# -> 1431         self._consolidate_inplace()
#    1432         indexer = (
#    1433             np.arange(indexer.start, indexer.stop, indexer.step, dtype="int64")
#
# ~/Documents/UFRGS/CURSOS/Aprendizado de Máquina/TAREFAS/VALIDAÇÃO CRUZADA/env/lib/python3.6/site-packages/pandas/core/internals/managers.py in _consolidate_inplace(self)
#     977     def _consolidate_inplace(self) -> None:
#     978         if not self.is_consolidated():
# --> 979             self.blocks = tuple(_consolidate(self.blocks))
#     980             self._is_consolidated = True
#     981             self._known_consolidated = True
#
# ~/Documents/UFRGS/CURSOS/Aprendizado de Máquina/TAREFAS/VALIDAÇÃO CRUZADA/env/lib/python3.6/site-packages/pandas/core/internals/managers.py in _consolidate(blocks)
#    1893     # sort by _can_consolidate, dtype
#    1894     gkey = lambda x: x._consolidate_key
# -> 1895     grouper = itertools.groupby(sorted(blocks, key=gkey), gkey)
#    1896
#    1897     new_blocks = []
#
# ~/Documents/UFRGS/CURSOS/Aprendizado de Máquina/TAREFAS/VALIDAÇÃO CRUZADA/env/lib/python3.6/site-packages/pandas/core/internals/managers.py in <lambda>(x)
#    1892     """
#    1893     # sort by _can_consolidate, dtype
# -> 1894     gkey = lambda x: x._consolidate_key
#    1895     grouper = itertools.groupby(sorted(blocks, key=gkey), gkey)
#    1896
#
# ~/Documents/UFRGS/CURSOS/Aprendizado de Máquina/TAREFAS/VALIDAÇÃO CRUZADA/env/lib/python3.6/site-packages/pandas/core/internals/blocks.py in _consolidate_key(self)
#     175     @property
#     176     def _consolidate_key(self):
# --> 177         return (self._can_consolidate, self.dtype.name)
#     178
#     179     @property
#
# ~/Documents/UFRGS/CURSOS/Aprendizado de Máquina/TAREFAS/VALIDAÇÃO CRUZADA/env/lib/python3.6/site-packages/numpy/core/_dtype.py in _name_get(dtype)
#     333
#     334     # append bit counts
# --> 335     if _name_includes_bit_suffix(dtype):
#     336         name += "{}".format(dtype.itemsize * 8)
#     337
#
# ~/Documents/UFRGS/CURSOS/Aprendizado de Máquina/TAREFAS/VALIDAÇÃO CRUZADA/env/lib/python3.6/site-packages/numpy/core/_dtype.py in _name_includes_bit_suffix(dtype)
#     312         # implied
#     313         return False
# --> 314     elif np.issubdtype(dtype, np.flexible) and _isunsized(dtype):
#     315         # unspecified
#     316         return False
#
# ~/Documents/UFRGS/CURSOS/Aprendizado de Máquina/TAREFAS/VALIDAÇÃO CRUZADA/env/lib/python3.6/site-packages/numpy/core/numerictypes.py in issubdtype(arg1, arg2)
#     385
#     386     """
# --> 387     if not issubclass_(arg1, generic):
#     388         arg1 = dtype(arg1).type
#     389     if not issubclass_(arg2, generic):
#
# ~/Documents/UFRGS/CURSOS/Aprendizado de Máquina/TAREFAS/VALIDAÇÃO CRUZADA/env/lib/python3.6/site-packages/numpy/core/numerictypes.py in issubclass_(arg1, arg2)
#     322     try:
#     323         return issubclass(arg1, arg2)
# --> 324     except TypeError:
#     325         return False
#     326
#
# KeyboardInterrupt:
